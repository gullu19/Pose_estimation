# %%
import cv2
import mediapipe as mp

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture("C:/Users/Admin/Documents/AI Engineer - ProductizeTech Assignment/task_4_video.mp4")  # Replace with path to your video

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert BGR image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Flip the image horizontally for a later selfie-view display
        image = cv2.flip(image, 1)

        # Set flag to draw landmarks on the image
        draw_landmarks = True

        # Detect the pose of the person in the image
        results = pose.process(image)

        # Draw the pose landmarks on the image
        if draw_landmarks and results.pose_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
                connection_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2))

        # Convert RGB image back to BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Display the resulting image
        cv2.imshow("Pose_Detection", image)

        if cv2.waitKey(1) == ord("q"):
            break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 40
#      37         image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
#      39         # Display the resulting image
# ---> 40         cv2.imwrite("Pose_Detection.avi", image)
#      42         #if cv2.waitKey(1) == ord("q"):
#      43             #break
#      45 cap.release()
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\imgcodecs\src\loadsave.cpp:692: error: (-2:Unspecified error) could not find a writer for the specified extension in function 'cv::imwrite_'

# %%
import cv2
import mediapipe as mp

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture("C:/Users/Admin/Documents/AI Engineer - ProductizeTech Assignment/task_4_video.mp4")  # Replace with path to your video

# Get video properties
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create a VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
output_video = cv2.VideoWriter('output_task_4.mp4', fourcc, fps, (width, height))

with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break

        # Convert BGR image to RGB
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)

        # Flip the image horizontally for a later selfie-view display
        #image = cv2.flip(image, 1)

        # Set flag to draw landmarks on the image
        draw_landmarks = True

        # Detect the pose of the person in the image
        results = pose.process(image)

        # Draw the pose landmarks on the image
        if draw_landmarks and results.pose_landmarks:
            mp_drawing.draw_landmarks(
                image,
                results.pose_landmarks,
                mp_pose.POSE_CONNECTIONS,
                landmark_drawing_spec=mp_drawing.DrawingSpec(color=(0, 0, 255), thickness=2, circle_radius=2),
                connection_drawing_spec=mp_drawing.DrawingSpec(color=(0, 255, 0), thickness=2))

        # Convert RGB image back to BGR
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)

        # Write the frame to the output video
        output_video.write(image)

        if cv2.waitKey(1) == ord("q"):
            break

cap.release()
output_video.release()
cv2.destroyAllWindows()
